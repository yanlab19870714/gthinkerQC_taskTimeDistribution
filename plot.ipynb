# %% [markdown]
# # Load Youtube Data Task Statistics

# %%
import pandas as pd

df = pd.read_csv("youtube.csv")
df.head(5)
# Out:
#    rootID   |V|    |E|  max_deg  avg_deg  core_number(depth)  deg1  deg2  \
# 0   18880   578  12965      249   22.430                  29   249   231
# 1    5456  3046  87294     1353   28.660                  49  1353  1136
# 2    5152  1285  31185      526   24.270                  33   526   473
# 3    9728  1638  36634      601   22.365                  31   601   470
# 4    7376  1003  25293      541   25.215                  38   541   389
#
#    deg3  deg4  ...  core2  core3  core4  core5  core6  core7  core8  core9  \
# 0   194   167  ...     29     29     29     29     29     29     29     29
# 1  1123  1107  ...     49     49     49     49     49     49     49     49
# 2   360   354  ...     33     33     33     33     33     33     33     33
# 3   431   415  ...     31     31     31     31     31     31     31     31
# 4   384   384  ...     38     38     38     38     38     38     38     38
#
#    core10  time(ms)
# 0      29      48.0
# 1      49    2195.0
# 2      33     177.0
# 3      31     267.0
# 4      38     113.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Sort by Time

# %%
df.sort_values("time(ms)", inplace=True)
df.tail(10)
# Out:
#        rootID    |V|     |E|  max_deg  avg_deg  core_number(depth)  deg1  \
# 2388    19195   2570   72678     1583   28.280                  43  1583
# 1581    19786   3588   82727     1417   23.055                  37  1417
# 4553    17345   3228  100177     2127   31.035                  49  2127
# 9727    19107   2646   75747     1646   28.625                  44  1646
# 12942   19366   2755   78375     1597   28.450                  45  1597
# 556     15056   5074  162249     2721   31.975                  50  2721
# 11756   18725   3177  101008     1850   31.795                  49  1850
# 10739   19780   2321   55094     1320   23.735                  38  1320
# 4096    18892   3723  113828     1849   30.575                  46  1849
# 628         0  26235  694686     7105   26.480                  51  7105
#
#        deg2  deg3  deg4  ...  core2  core3  core4  core5  core6  core7  core8  \
# 2388    684   660   555  ...     43     43     43     43     43     43     43
# 1581   1012   691   671  ...     37     37     37     37     37     37     37
# 4553    759   671   653  ...     49     49     49     49     49     49     49
# 9727    692   657   565  ...     44     44     44     44     44     44     44
# 12942   934   853   566  ...     45     45     45     45     45     45     45
# 556    1546   890   840  ...     50     50     50     50     50     50     50
# 11756  1059   978   672  ...     49     49     49     49     49     49     49
# 10739   645   597   532  ...     38     38     38     38     38     38     38
# 4096   1303   831   719  ...     46     46     46     46     46     46     46
# 628    5544  2393  2159  ...     51     51     51     51     51     51     51
#
#        core9  core10   time(ms)
# 2388      43      43    13033.0
# 1581      37      37    13407.0
# 4553      49      49    13623.0
# 9727      44      44    13893.0
# 12942     45      45    15011.0
# 556       50      50    15015.0
# 11756     49      49    15267.0
# 10739     38      38    15584.0
# 4096      46      46    16881.0
# 628       51      51  3645905.0
#
# [10 rows x 27 columns]

# %% [markdown]
# # |V| v.s. Time Plot

# %%
import numpy as np

x = np.array(df['|V|'])
y = np.array(df['time(ms)'])

# %% [markdown]
# ### Ratio of {Total Time by All Tasks} / {Time of the Most Expensive Task}

# %%
np.sum(y)/np.max(y)
# Out:
# 5.513795340251598

# %% [markdown]
# ### Kick out the last point which is an outlier that is on the far upper-right corner

# %%
x = x[:-1]
y = y[:-1]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Number of Vertex in Task-Subgraph', fontsize=25)
plt.ylabel('Task-Subgraph Mining Time (ms)', fontsize=25)

plt.scatter(x, y, s=16)

plt.savefig('V.pdf')
plt.show()

# %% [markdown]
# # max_deg v.s. Time Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(df['max_deg'])
y = np.array(df['time(ms)'])

x = x[:-1]
y = y[:-1]

plt.figure(figsize=(20,10))

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Maximum Vertex Degree in Task-Subgraph', fontsize=25)
plt.ylabel('Task-Subgraph Mining Time (ms)', fontsize=25)

plt.scatter(x, y, s=16)

plt.savefig('max_deg.pdf')
plt.show()

# %% [markdown]
# # avg_deg v.s. Time Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(df['avg_deg'])
y = np.array(df['time(ms)'])

x = x[:-1]
y = y[:-1]

plt.figure(figsize=(20,10))

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Average Vertex Degree in Task-Subgraph', fontsize=25)
plt.ylabel('Task-Subgraph Mining Time (ms)', fontsize=25)

plt.scatter(x, y, s=16)

plt.savefig('avg_deg.pdf')
plt.show()

# %% [markdown]
# # core_number(depth) v.s. Time Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(df['core_number(depth)'])
y = np.array(df['time(ms)'])

x = x[:-1]
y = y[:-1]

plt.figure(figsize=(20,10))

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Core Number in Task-Subgraph', fontsize=25)
plt.ylabel('Task-Subgraph Mining Time (ms)', fontsize=25)

plt.scatter(x, y, s=16)

plt.savefig('core.pdf')
plt.show()
